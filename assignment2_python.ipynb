# %% [markdown]
# <img src="https://datasciencedegree.wisconsin.edu/wp-content/themes/data-gulp/images/logo.svg" width="300">

# %% [markdown]
# # Assignment 2
#
# The second assignment has you play with control flow, to solve two classic problems in the training of a programmer.
# 1. FizzBuzz, with a woof modification.  This one trains you on if/elseif/else, and some arithmetic operators.
# 2. Mortgage calculator.  Good for learning some formatting, looping, and checking for problematic input.

# %% [markdown]
# ## Problem 1(a).  Fizz, Buzz, Woof.
#
# 🎯 Write a program that prints the numbers from 1 to 150, except . . .
#
# * When you get a number that's divisible by 3, print "Fizz" instead.
# * When you get a number that's divisible by 5, print "Buzz" instead.
# * When you get a number that's divisible by 7, print "Woof" instead.
#
# If a number is divisible by several of these values, print the appropriate words in the corresponding order.  For example, for 15 you should print "Fizz Buzz", for 35 you should print "Buzz Woof", and for 105 you should print "Fizz Buzz Woof".
#
# 🎯 Consider learning how to write Python functions now, to help reduce the overall number of lines of code you write.  Function come next lesson, but are one of the fundamental programming constructs in any language.  Embrace them.

# %%
count = 1  # Set Count to 1 

while (count <= 150): # Loop for all numbers between 1 to 150.  Check remainder of all rows.
    if (count % 3) == 0 and (count % 5) == 0 and (count % 7) == 0:
        print ("Fizz Buzz Woof")
        count = count +1
    elif (count % 5) == 0 and (count % 7) == 0:
        print ("Buzz Woof")
        count = count +1
    elif (count % 3) == 0 and (count % 5) == 0:
        print ("Fizz Buzz")
        count = count +1
    elif (count % 3) == 0 and (count % 7) == 0:
        print ("Fizz Woof")
        count = count +1
    elif (count % 3) == 0:
        print ("Fizz")
        count = count +1
    elif (count % 5) == 0:
        print ("Buzz")
        count = count + 1
    elif (count % 7) == 0:
        print ("Woof")
        count = count +1
    else:
        print (count)
        count = count + 1
# Out:
# 1
# 2
# Fizz
# 4
# Buzz
# Fizz
# Woof
# 8
# Fizz
# Buzz
# 11
# Fizz
# 13
# Woof
# Fizz Buzz
# 16
# 17
# Fizz
# 19
# Buzz
# Fizz Woof
# 22
# 23
# Fizz
# Buzz
# 26
# Fizz
# Woof
# 29
# Fizz Buzz
# 31
# 32
# Fizz
# 34
# Buzz Woof
# Fizz
# 37
# 38
# Fizz
# Buzz
# 41
# Fizz Woof
# 43
# 44
# Fizz Buzz
# 46
# 47
# Fizz
# Woof
# Buzz
# Fizz
# 52
# 53
# Fizz
# Buzz
# Woof
# Fizz
# 58
# 59
# Fizz Buzz
# 61
# 62
# Fizz Woof
# 64
# Buzz
# Fizz
# 67
# 68
# Fizz
# Buzz Woof
# 71
# Fizz
# 73
# 74
# Fizz Buzz
# 76
# Woof
# Fizz
# 79
# Buzz
# Fizz
# 82
# 83
# Fizz Woof
# Buzz
# 86
# Fizz
# 88
# 89
# Fizz Buzz
# Woof
# 92
# Fizz
# 94
# Buzz
# Fizz
# 97
# Woof
# Fizz
# Buzz
# 101
# Fizz
# 103
# 104
# Fizz Buzz Woof
# 106
# 107
# Fizz
# 109
# Buzz
# Fizz
# Woof
# 113
# Fizz
# Buzz
# 116
# Fizz
# 118
# Woof
# Fizz Buzz
# 121
# 122
# Fizz
# 124
# Buzz
# Fizz Woof
# 127
# 128
# Fizz
# Buzz
# 131
# Fizz
# Woof
# 134
# Fizz Buzz
# 136
# 137
# Fizz
# 139
# Buzz Woof
# Fizz
# 142
# 143
# Fizz
# Buzz
# 146
# Fizz Woof
# 148
# 149
# Fizz Buzz

# %% [markdown]
# ## Problem 1(b) [Optional].  Direction of Play.
#
# Fizz, Buzz, Woof originates as a children's game.  The children sit in a circle.  Initially, play moves clockwise, with each child saying a number in turn.  After "Fizz", play switches direction, and after "Buzz", play switches direction again.  The direction of play continues to switch each time an *odd* number of non-integer words is spoken.  However, two-word substitutions, such as "Fizz Buzz", do *not* change direction of play, but three-word substitutions *do* change the direction of play.
#
# 🎯 Modify your program from 1(a) so that it indicates the direction of play.  For example, your output should begin:
#
# ```
# Clockwise!
# 1
# 2
# Fizz
# Counterclockwise!
# 4
# Buzz
# Clockwise!
# Fizz
# Counterclockwise!
# Woof
# Clockwise!
# 8
# Fizz
# Counterclockwise!
# Buzz
# Clockwise!
# 11
# Fizz
# Counterclockwise!
# 13
# Woof
# Clockwise!
# Fizz Buzz
# 16
# ```

# %%
count = 1
direction_count = 2
Direction = ('Clockwise!','CounterClockwise!')
print (Direction[direction_count % 2])

while (count <= 150):
    if (count % 3) == 0 and (count % 5) == 0 and (count % 7) == 0:
        print ("Fizz Buzz Woof")
        count = count +1
        direction_count = direction_count + 1
        print (Direction[direction_count % 2])
    elif (count % 5) == 0 and (count % 7) == 0:
        print ("Buzz Woof")
        direction_count = direction_count + 1
        print (Direction[direction_count % 2])
        count = count +1
    elif (count % 3) == 0 and (count % 5) == 0:
        print ("Fizz Buzz")
        direction_count = direction_count + 1
        print (Direction[direction_count % 2])
        count = count +1
    elif (count % 3) == 0 and (count % 7) == 0:
        print ("Fizz Woof")
        direction_count = direction_count + 1
        print (Direction[direction_count % 2])
        count = count +1
    elif (count % 3) == 0:
        print ("Fizz")
        direction_count = direction_count + 1
        print (Direction[direction_count % 2])
        count = count +1
    elif (count % 5) == 0:
        print ("Buzz")
        direction_count = direction_count + 1
        print (Direction[direction_count % 2])
        count = count + 1
    elif (count % 7) == 0:
        print ("Woof")
        direction_count = direction_count + 1
        print (Direction[direction_count % 2])
        count = count +1
    else:
        print (count)
        count = count + 1
# Out:
# Clockwise!
# 1
# 2
# Fizz
# CounterClockwise!
# 4
# Buzz
# Clockwise!
# Fizz
# CounterClockwise!
# Woof
# Clockwise!
# 8
# Fizz
# CounterClockwise!
# Buzz
# Clockwise!
# 11
# Fizz
# CounterClockwise!
# 13
# Woof
# Clockwise!
# Fizz Buzz
# CounterClockwise!
# 16
# 17
# Fizz
# Clockwise!
# 19
# Buzz
# CounterClockwise!
# Fizz Woof
# Clockwise!
# 22
# 23
# Fizz
# CounterClockwise!
# Buzz
# Clockwise!
# 26
# Fizz
# CounterClockwise!
# Woof
# Clockwise!
# 29
# Fizz Buzz
# CounterClockwise!
# 31
# 32
# Fizz
# Clockwise!
# 34
# Buzz Woof
# CounterClockwise!
# Fizz
# Clockwise!
# 37
# 38
# Fizz
# CounterClockwise!
# Buzz
# Clockwise!
# 41
# Fizz Woof
# CounterClockwise!
# 43
# 44
# Fizz Buzz
# Clockwise!
# 46
# 47
# Fizz
# CounterClockwise!
# Woof
# Clockwise!
# Buzz
# CounterClockwise!
# Fizz
# Clockwise!
# 52
# 53
# Fizz
# CounterClockwise!
# Buzz
# Clockwise!
# Woof
# CounterClockwise!
# Fizz
# Clockwise!
# 58
# 59
# Fizz Buzz
# CounterClockwise!
# 61
# 62
# Fizz Woof
# Clockwise!
# 64
# Buzz
# CounterClockwise!
# Fizz
# Clockwise!
# 67
# 68
# Fizz
# CounterClockwise!
# Buzz Woof
# Clockwise!
# 71
# Fizz
# CounterClockwise!
# 73
# 74
# Fizz Buzz
# Clockwise!
# 76
# Woof
# CounterClockwise!
# Fizz
# Clockwise!
# 79
# Buzz
# CounterClockwise!
# Fizz
# Clockwise!
# 82
# 83
# Fizz Woof
# CounterClockwise!
# Buzz
# Clockwise!
# 86
# Fizz
# CounterClockwise!
# 88
# 89
# Fizz Buzz
# Clockwise!
# Woof
# CounterClockwise!
# 92
# Fizz
# Clockwise!
# 94
# Buzz
# CounterClockwise!
# Fizz
# Clockwise!
# 97
# Woof
# CounterClockwise!
# Fizz
# Clockwise!
# Buzz
# CounterClockwise!
# 101
# Fizz
# Clockwise!
# 103
# 104
# Fizz Buzz Woof
# CounterClockwise!
# 106
# 107
# Fizz
# Clockwise!
# 109
# Buzz
# CounterClockwise!
# Fizz
# Clockwise!
# Woof
# CounterClockwise!
# 113
# Fizz
# Clockwise!
# Buzz
# CounterClockwise!
# 116
# Fizz
# Clockwise!
# 118
# Woof
# CounterClockwise!
# Fizz Buzz
# Clockwise!
# 121
# 122
# Fizz
# CounterClockwise!
# 124
# Buzz
# Clockwise!
# Fizz Woof
# CounterClockwise!
# 127
# 128
# Fizz
# Clockwise!
# Buzz
# CounterClockwise!
# 131
# Fizz
# Clockwise!
# Woof
# CounterClockwise!
# 134
# Fizz Buzz
# Clockwise!
# 136
# 137
# Fizz
# CounterClockwise!
# 139
# Buzz Woof
# Clockwise!
# Fizz
# CounterClockwise!
# 142
# 143
# Fizz
# Clockwise!
# Buzz
# CounterClockwise!
# 146
# Fizz Woof
# Clockwise!
# 148
# 149
# Fizz Buzz
# CounterClockwise!

# %% [markdown]
# ---
#
# ## Problem 2(a).  Mortgage Calculator.
#
# Buying a house is one of the biggest financial transactions that many people ever undertake.  Even a small difference in interest rates or monthly payments can make a large difference in how much you ultimately pay for your mortgage.  However, these details are often buried in masses of paperwork--so it pays to be able to calculate the long-term cost of a mortgage yourself.
#
# In a mortgage, the bank lends you a certain amount of principal to purchase a house at a certain interest rate.  Every month, the amount you owe (the balance) first increases due to interest:  1/12 of the interest rate times the current balance.  Then the balance decreases due to your monthly payment.
#
# For example, suppose you borrow $\$100,000$ at $5\%$ annual interest, with $\$500$ monthly payments.  In the first month, the interest increases the balance by $\$416.67$, and then your payment reduces it by $\$500$, for a remaining balance of $\$99,916.67$.  In the second month, the interest charge is $\$416.32$, and the remaining balance is
# $\$99,832.99$.
#
# If you continue this process, you get an amortization table like this:
#
# ```
# month	 payment	 interest	 balance
# 1 	     500 		 416.67 	 99916.67
# 2 	     500 		 416.32 	 99832.99
# 3 	     500 		 415.97 	 99748.96
# 4 	     500 		 415.62 	 99664.58
# 5 	     500 		 415.27 	 99579.85
# 6 	     500 		 414.92 	 99494.76
# 7 	     500 		 414.56 	 99409.32
# 8 	     500 		 414.21 	 99323.53
# 9 	     500 		 413.85 	 99237.38
# 10 	    500 		 413.49 	 99150.87
#
# ```
#
# You can also compute the total amount of time and money to pay off the mortgage.  In this example, it takes 35 years and 11 months, and the total amount paid is approximately $\$215,458.84$.
#
# ---
#
# 🎯 Create a mortgage calculator that takes as input the *principal loan amount*, *interest rate*, and *monthly payment*.  As output, your calculator should generate an *amortization table*, and compute how many *years and months* it took to pay off the mortgage, and report the *total amount of payments* over that time.
#
#
# ###### Things to consider when implementing the calculator
# 1.  For dollar values, only display two digits of precision after the decimal point.
#   * You can assume that the bank will not round internally!
#   * You must not round internally either!)
# 2.  The final payment will almost certainly be smaller than the others, so be careful to check for that case so you don't end up with a negative balance.  The final balance must be 0.
# 3.  If the monthly payment is too small, the balance will go up every month!
#   * If this happens, the program should stop and display an appropriate error message.
#   * Manually stopping your code in this case is not considered a solution -- your *submitted* code must detect the problem itself, and not enter an infinite loop.
# 4.  If you accidentally create an infinite loop during development and testing, interrupt or restart the kernel.  See the `Kernel` menu up top.
# 5.  Use the modulus or $\%$  operator to separate the years and months.
# 6.  Your program should only display the columns requested, and the rows should be formatted to appear under the appropriate heading.

# %%
##Gather Input Values for calculations
principal_loan_amount =  int(input('Please enter the principal:'))
year_interest_rate =  int(input('please enter the yearly interest rate.  ie 5 for 5%:'))
month_interest_rate =  (year_interest_rate /100) / 12
monthly_payment = int(input('please enter the monthly payment:'))

##Reset Variables
remaining_balance = principal_loan_amount 
month_count = 1
temp_amount = 0
year_count = 0

##Print Header
print ('month_count','monthly_payment','principal_payment','remaining_balance')
    
##Loop    
while (remaining_balance > 0):
    principal_payment =  round((remaining_balance * month_interest_rate),2) 
    remaining_balance =  round((remaining_balance + principal_payment -  monthly_payment),2)
    if (remaining_balance < 0):
        remaining_balance = 0
    if (remaining_balance >= principal_loan_amount):
        print('Remaining Balance > Principal Loan Amount. Payment must be higher')
        break
    print (month_count,'         ' , monthly_payment,'           ' ,principal_payment,'           ' ,remaining_balance)
    if (remaining_balance > 0):
        month_count = month_count + 1

##Print Footer of Report.
if (remaining_balance < principal_loan_amount):        
    year_count = (month_count // 12)  
    print('Years to pay off Loan ', year_count)

    remaining_months = month_count - (year_count * 12)
    print('Additional Months to pay off Loan ', remaining_months)

    estimated_payments = (month_count * monthly_payment)
    print('Estimated Payments over the course of the loan $', estimated_payments)
# Out:
# Please enter the principal:500
# please enter the yearly interest rate.  ie 5 for 5%:5
# please enter the monthly payment:1
# month_count monthly_payment principal_payment remaining_balance
# Remaining Balance > Principal Loan Amount. Payment must be higher

# %% [markdown]
# ## Problem 2(b). Testing.
#
# When writing complicated code, it is always a good idea to test your code on simple examples.
#
# 🎯 Use the following test cases to make sure your code matches calculations you can perform by hand. (Of course, if it does not match, please fix your code.)
# 🎯 For each test case, print the results.
#
# For each, use $\$500$ for the principal, and an annual interest rate of $5\%$.
# 1. Monthly Payment: $\$100$
# 2. Monthly Payment: $\$500$
# 3. Monthly Payment: $\$1$

# %%
#for a monthly payment of 100, the payoff was 6 months.
1           100             2.08             402.08
2           100             1.68             303.76
3           100             1.27             205.03
4           100             0.85             105.88
5           100             0.44             6.32
6           100             0.03             0
#for a monthly payment of 500, the payoff was 2 months.
1           500             2.08             2.08
2           500             0.01             0
#for a monthly pament of 1, this did not meet the minimum payment amount and would result in a loop.  The program exited.

# %% [markdown]
# ## Problem 2(c). Calculator Analysis.
#
# 🎯 Answer the following questions in a markdown cell.
#
# 1.  Describe in your own words how the mortgage calculator works.  What are the steps you are computing?  What are you keeping track of in each iteration?
# 2.	Suppose you had a mortgage with a principal of $\$250,000$, an interest rate of $4\%$, and a monthly payment of $\$1000$.
#   * How long would it take you to pay it off?
#   * How much would you have paid in total?
#   * Using a code cell, print the amortization schedule.

# %%
#1. The calculator takes inputs of all the variables including the monthly_payment, principal_payment and remaining_balance.  
# It keep tracks of the months to reach a balane of 0, and the remaining principal balance.
# It does a loop until there is no long a balance due.   If the remaining balance is greater than the original loan amount, it prints a message.
# In the loop, it calculates the amount of interest, adds that to the balance remaining, then subtracts the payment .
# It then iterates a counter, and does all the calculations again.
#
#2. To pay off the loan, it would take 44 Years, and 11 Months.
#  Estimated Payments over the course of the loan $ 539000
